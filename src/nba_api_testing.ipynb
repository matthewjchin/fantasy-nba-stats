# %%
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import commonplayerinfo
from nba_api.stats.static import players

# %%
# LeBron James
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)

custom_headers = {
    'Host': 'stats.nba.com',
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# %%
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544, proxy='127.0.0.1:80', headers=custom_headers, timeout=100)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/opt/anaconda3/envs/matt_py31010/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/opt/anaconda3/envs/matt_py31010/lib/python3.10/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/opt/anaconda3/envs/matt_py31010/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ...

# %%
player_info

# %%
player_info.get_response()
# Out:
# '{"resource":"commonplayerinfo","parameters":[{"PlayerID":2544},{"LeagueID":null}],"resultSets":[{"name":"CommonPlayerInfo","headers":["PERSON_ID","FIRST_NAME","LAST_NAME","DISPLAY_FIRST_LAST","DISPLAY_LAST_COMMA_FIRST","DISPLAY_FI_LAST","PLAYER_SLUG","BIRTHDATE","SCHOOL","COUNTRY","LAST_AFFILIATION","HEIGHT","WEIGHT","SEASON_EXP","JERSEY","POSITION","ROSTERSTATUS","GAMES_PLAYED_CURRENT_SEASON_FLAG","TEAM_ID","TEAM_NAME","TEAM_ABBREVIATION","TEAM_CODE","TEAM_CITY","PLAYERCODE","FROM_YEAR","TO_YEAR","DLEAGUE_FLAG","NBA_FLAG","GAMES_PLAYED_FLAG","DRAFT_YEAR","DRAFT_ROUND","DRAFT_NUMBER","GREATEST_75_FLAG"],"rowSet":[[2544,"LeBron","James","LeBron James","James, LeBron","L. James","lebron-james","1984-12-30T00:00:00","St. Vincent-St. Mary HS (OH)","USA","St. Vincent-St. Mary HS (OH)/USA","6-9","250",20,"23","Forward","Active","Y",1610612747,"Lakers","LAL","lakers","Los Angeles","lebron_james",2003,2023,"N","Y","Y","2003","1","1","Y"]]},{"name":"PlayerHeadlineStats","headers":["PLAYER_ID
# ...

# %%
player_info.get_normalized_json()
# Out:
# '{"CommonPlayerInfo": [{"PERSON_ID": 2544, "FIRST_NAME": "LeBron", "LAST_NAME": "James", "DISPLAY_FIRST_LAST": "LeBron James", "DISPLAY_LAST_COMMA_FIRST": "James, LeBron", "DISPLAY_FI_LAST": "L. James", "PLAYER_SLUG": "lebron-james", "BIRTHDATE": "1984-12-30T00:00:00", "SCHOOL": "St. Vincent-St. Mary HS (OH)", "COUNTRY": "USA", "LAST_AFFILIATION": "St. Vincent-St. Mary HS (OH)/USA", "HEIGHT": "6-9", "WEIGHT": "250", "SEASON_EXP": 20, "JERSEY": "23", "POSITION": "Forward", "ROSTERSTATUS": "Active", "GAMES_PLAYED_CURRENT_SEASON_FLAG": "Y", "TEAM_ID": 1610612747, "TEAM_NAME": "Lakers", "TEAM_ABBREVIATION": "LAL", "TEAM_CODE": "lakers", "TEAM_CITY": "Los Angeles", "PLAYERCODE": "lebron_james", "FROM_YEAR": 2003, "TO_YEAR": 2023, "DLEAGUE_FLAG": "N", "NBA_FLAG": "Y", "GAMES_PLAYED_FLAG": "Y", "DRAFT_YEAR": "2003", "DRAFT_ROUND": "1", "DRAFT_NUMBER": "1", "GREATEST_75_FLAG": "Y"}], "PlayerHeadlineStats": [{"PLAYER_ID": 2544, "PLAYER_NAME": "LeBron James", "TimeFrame": "2023-24", "PTS": 24.
# ...

# %%
# Anthony Davis

from nba_api.stats.endpoints import playercareerstats


ad_career = playercareerstats.PlayerCareerStats(player_id="203076")
ad_career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203076   2012-13        00  1610612740               NOH        20.0
# 1      203076   2013-14        00  1610612740               NOP        21.0
# 2      203076   2014-15        00  1610612740               NOP        22.0
# 3      203076   2015-16        00  1610612740               NOP        23.0
# 4      203076   2016-17        00  1610612740               NOP        24.0
# 5      203076   2017-18        00  1610612740               NOP        25.0
# 6      203076   2018-19        00  1610612740               NOP        26.0
# 7      203076   2019-20        00  1610612747               LAL        27.0
# 8      203076   2020-21        00  1610612747               LAL        28.0
# 9      203076   2021-22        00  1610612747               LAL        29.0
# 10     203076   2022-23        00  1610612747               LAL        30.0
# ...

# %%
from nba_api.stats.static import players
nba_players = players.get_active_players()
print("Number of players fetched: {}".format(len(nba_players)))
# Out:
# Number of players fetched: 531

# %%
nba_players
# Out:
# [{'id': 1630173,
#   'full_name': 'Precious Achiuwa',
#   'first_name': 'Precious',
#   'last_name': 'Achiuwa',
#   'is_active': True},
#  {'id': 203500,
#   'full_name': 'Steven Adams',
#   'first_name': 'Steven',
#   'last_name': 'Adams',
#   'is_active': True},
#  {'id': 1628389,
#   'full_name': 'Bam Adebayo',
#   'first_name': 'Bam',
#   'last_name': 'Adebayo',
#   'is_active': True},
#  {'id': 1630534,
#   'full_name': 'Ochai Agbaji',
#   'first_name': 'Ochai',
#   'last_name': 'Agbaji',
#   'is_active': True},
#  {'id': 1630583,
#   'full_name': 'Santi Aldama',
#   'first_name': 'Santi',
#   'last_name': 'Aldama',
#   'is_active': True},
#  {'id': 1629638,
#   'full_name': 'Nickeil Alexander-Walker',
#   'first_name': 'Nickeil',
#   'last_name': 'Alexander-Walker',
#   'is_active': True},
#  {'id': 1628960,
#   'full_name': 'Grayson Allen',
#   'first_name': 'Grayson',
#   'last_name': 'Allen',
#   'is_active': True},
#  {'id': 1628386,
#   'full_name': 'Jarrett Allen',
# ...

# %%
nba_players[0]
# Out:
# {'id': 1630173,
#  'full_name': 'Precious Achiuwa',
#  'first_name': 'Precious',
#  'last_name': 'Achiuwa',
#  'is_active': True}

# %%
# Stephen Curry

sc_info = dict()

for x in nba_players:
    if x['full_name'] == "Stephen Curry":
        # print(x)
        # print(type(x))
        sc_info = x
        # print("player id:", x['id'])

sc_info.get('id')
# Out:
# 201939

# %%
# Shai Gilgeous-Alexander

for x in nba_players:
    if x['full_name'] == "Shai Gilgeous-Alexander":
        print(x)
# Out:
# {'id': 1628983, 'full_name': 'Shai Gilgeous-Alexander', 'first_name': 'Shai', 'last_name': 'Gilgeous-Alexander', 'is_active': True}

# %%
# Active players with last name "Thompson"

for x in nba_players:
    if x['last_name'] == "Thompson":
        print(x)
# Out:
# {'id': 1641708, 'full_name': 'Amen Thompson', 'first_name': 'Amen', 'last_name': 'Thompson', 'is_active': True}
# {'id': 1641709, 'full_name': 'Ausar Thompson', 'first_name': 'Ausar', 'last_name': 'Thompson', 'is_active': True}
# {'id': 202691, 'full_name': 'Klay Thompson', 'first_name': 'Klay', 'last_name': 'Thompson', 'is_active': True}
# {'id': 202684, 'full_name': 'Tristan Thompson', 'first_name': 'Tristan', 'last_name': 'Thompson', 'is_active': True}

# %%
type(x['id'])
# Out:
# int

# %%
# Stephen Curry stats

sc_stats = playercareerstats.PlayerCareerStats(player_id=sc_info.get('id'))

# %%
type(sc_stats)
# Out:
# nba_api.stats.endpoints.playercareerstats.PlayerCareerStats

# %%
# All of Curry's statistics all in different data frames. 

sc_stats.get_data_frames()
# Out:
# [    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
#  0      201939   2009-10        00  1610612744               GSW        22.0
#  1      201939   2010-11        00  1610612744               GSW        23.0
#  2      201939   2011-12        00  1610612744               GSW        24.0
#  3      201939   2012-13        00  1610612744               GSW        25.0
#  4      201939   2013-14        00  1610612744               GSW        26.0
#  5      201939   2014-15        00  1610612744               GSW        27.0
#  6      201939   2015-16        00  1610612744               GSW        28.0
#  7      201939   2016-17        00  1610612744               GSW        29.0
#  8      201939   2017-18        00  1610612744               GSW        30.0
#  9      201939   2018-19        00  1610612744               GSW        31.0
#  10     201939   2019-20        00  1610612744               GSW        32.0
# ...

# %%
type(sc_stats.get_data_frames())
# Out:
# list

# %%
sc_stats.get_data_frames()[0]

# len(sc_stats.get_data_frames())
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201939   2009-10        00  1610612744               GSW        22.0
# 1      201939   2010-11        00  1610612744               GSW        23.0
# 2      201939   2011-12        00  1610612744               GSW        24.0
# 3      201939   2012-13        00  1610612744               GSW        25.0
# 4      201939   2013-14        00  1610612744               GSW        26.0
# 5      201939   2014-15        00  1610612744               GSW        27.0
# 6      201939   2015-16        00  1610612744               GSW        28.0
# 7      201939   2016-17        00  1610612744               GSW        29.0
# 8      201939   2017-18        00  1610612744               GSW        30.0
# 9      201939   2018-19        00  1610612744               GSW        31.0
# 10     201939   2019-20        00  1610612744               GSW        32.0
# ...

# %%
type(x['full_name'])
# Out:
# str

# %%
type(sc_stats.get_data_frames()[0])
# Out:
# pandas.core.frame.DataFrame

# %%
sc_stats.get_normalized_dict()
# Out:
# {'SeasonTotalsRegularSeason': [{'PLAYER_ID': 201939,
#    'SEASON_ID': '2009-10',
#    'LEAGUE_ID': '00',
#    'TEAM_ID': 1610612744,
#    'TEAM_ABBREVIATION': 'GSW',
#    'PLAYER_AGE': 22.0,
#    'GP': 80,
#    'GS': 77,
#    'MIN': 2896.0,
#    'FGM': 528,
#    'FGA': 1143,
#    'FG_PCT': 0.462,
#    'FG3M': 166,
#    'FG3A': 380,
#    'FG3_PCT': 0.437,
#    'FTM': 177,
#    'FTA': 200,
#    'FT_PCT': 0.885,
#    'OREB': 48,
#    'DREB': 308,
#    'REB': 356,
#    'AST': 472,
#    'STL': 152,
#    'BLK': 19,
#    'TOV': 243,
#    'PF': 252,
#    'PTS': 1399},
#   {'PLAYER_ID': 201939,
#    'SEASON_ID': '2010-11',
#    'LEAGUE_ID': '00',
#    'TEAM_ID': 1610612744,
#    'TEAM_ABBREVIATION': 'GSW',
#    'PLAYER_AGE': 23.0,
#    'GP': 74,
#    'GS': 74,
#    'MIN': 2489.0,
#    'FGM': 505,
#    'FGA': 1053,
#    'FG_PCT': 0.48,
#    'FG3M': 151,
#    'FG3A': 342,
#    'FG3_PCT': 0.442,
#    'FTM': 212,
#    'FTA': 227,
#    'FT_PCT': 0.934,
#    'OREB': 52,
#    'DREB': 234,
# ...

# %%
nba_players[399]
# Out:
# {'id': 1626196,
#  'full_name': 'Josh Richardson',
#  'first_name': 'Josh',
#  'last_name': 'Richardson',
#  'is_active': True}

# %%
sc_stats.get_data_frames()[0]['PTS']
# Out:
# 0     1399
# 1     1373
# 2      383
# 3     1786
# 4     1873
# 5     1900
# 6     2375
# 7     1999
# 8     1346
# 9     1881
# 10     104
# 11    2015
# 12    1630
# 13    1648
# 14    1289
# Name: PTS, dtype: int64

# %%
sum(sc_stats.get_data_frames()[0]['PTS'])
# Out:
# 23001
